# %%
import pandas as pd

# %%
data = pd.read_csv('test_data.csv')

# %%
data.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2018-M020     Brisbane    Hard         32             A      20180101
# 1  2018-M020     Brisbane    Hard         32             A      20180101
# 2  2018-M020     Brisbane    Hard         32             A      20180101
# 3  2018-M020     Brisbane    Hard         32             A      20180101
# 4  2018-M020     Brisbane    Hard         32             A      20180101
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        271     105992          NaN          NaN  ...    47.0     33.0
# 1        272     111577          NaN          NaN  ...    41.0     25.0
# 2        273     104797          NaN          NaN  ...    53.0     37.0
# 3        275     200282          NaN           WC  ...    43.0     33.0
# 4        276     111581          NaN            Q  ...    35.0     28.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# ...

# %%
data.shape
# Out:
# (2889, 49)

# %%
data.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
djokow = data[data['winner_name'] == 'Novak Djokovic']
djokow.head()
# Out:
#      tourney_id         tourney_name surface  draw_size tourney_level  \
# 179    2018-580      Australian Open    Hard        128             G
# 223    2018-580      Australian Open    Hard        128             G
# 245    2018-580      Australian Open    Hard        128             G
# 1062  2018-0410  Monte Carlo Masters    Clay         64             M
# 1079  2018-0410  Monte Carlo Masters    Clay         64             M
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 179       20180115        141     104925         14.0          NaN  ...
# 223       20180115        221     104925         14.0          NaN  ...
# 245       20180115        311     104925         14.0          NaN  ...
# 1062      20180416        265     104925          9.0          NaN  ...
# 1079      20180416        283     104925          9.0          NaN  ...
#
#      l_1stIn l_1stWon  l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# ...

# %%
djokow[djokow['tourney_level'] == 'G'].count()
# Out:
# 31

# %%
djokol = data[data['loser_name'] == 'Novak Djokovic']
djokol.head()
# Out:
#      tourney_id          tourney_name surface  draw_size tourney_level  \
# 256    2018-580       Australian Open    Hard        128             G
# 758   2018-M006  Indian Wells Masters    Hard        128             M
# 861   2018-M007         Miami Masters    Hard        128             M
# 1088  2018-0410   Monte Carlo Masters    Clay         64             M
# 1125  2018-0425             Barcelona    Clay         64             A
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 256       20180115        406     111202          NaN          NaN  ...
# 758       20180305        242     106121          NaN            Q  ...
# 861       20180319        250     105332          NaN          NaN  ...
# 1088      20180416        292     106233          5.0          NaN  ...
# 1125      20180423        282     105373          NaN            Q  ...
#
#      l_1stIn l_1stWon  l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# ...

# %%
djokol[djokol['tourney_level'] == 'G']['surface'].count()
# Out:
# 6

# %%
djokol[djokol['tourney_level'] == 'G'].count()/djokow[djokow['tourney_level'] == 'G'].count()
# Out:
# 0.1935483870967742

# %%
data['tourney_level'].value_counts()
# Out:
# A    1547
# M     567
# G     508
# D     236
# F      31
# Name: tourney_level, dtype: int64
