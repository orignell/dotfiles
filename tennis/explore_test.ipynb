# %%
import pandas as pd

# %%
data = pd.read_csv('test_data.csv')

# %%
data.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2018-M020     Brisbane    Hard         32             A      20180101
# 1  2018-M020     Brisbane    Hard         32             A      20180101
# 2  2018-M020     Brisbane    Hard         32             A      20180101
# 3  2018-M020     Brisbane    Hard         32             A      20180101
# 4  2018-M020     Brisbane    Hard         32             A      20180101
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        271     105992          NaN          NaN  ...    47.0     33.0
# 1        272     111577          NaN          NaN  ...    41.0     25.0
# 2        273     104797          NaN          NaN  ...    53.0     37.0
# 3        275     200282          NaN           WC  ...    43.0     33.0
# 4        276     111581          NaN            Q  ...    35.0     28.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# ...

# %%
data.shape
# Out:
# (2889, 49)

# %%
data.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
data[data.isnull()].count()
# Out:
# tourney_id            0
# tourney_name          0
# surface               0
# draw_size             0
# tourney_level         0
# tourney_date          0
# match_num             0
# winner_id             0
# winner_seed           0
# winner_entry          0
# winner_name           0
# winner_hand           0
# winner_ht             0
# winner_ioc            0
# winner_age            0
# loser_id              0
# loser_seed            0
# loser_entry           0
# loser_name            0
# loser_hand            0
# loser_ht              0
# loser_ioc             0
# loser_age             0
# score                 0
# best_of               0
# round                 0
# minutes               0
# w_ace                 0
# w_df                  0
# w_svpt                0
# w_1stIn               0
# w_1stWon              0
# w_2ndWon              0
# w_SvGms               0
# w_bpSaved             0
# w_bpFaced             0
# l_ace                 0
# l_df                  0
# ...
